# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
from sklearn.cluster import KMeans

# %%
raw_data = pd.read_csv('Countries_exercise.csv')
raw_data
# Out:
#              name   Longitude   Latitude
# 0           Aruba  -69.982677  12.520880
# 1     Afghanistan   66.004734  33.835231
# 2          Angola   17.537368 -12.293361
# 3        Anguilla  -63.064989  18.223959
# 4         Albania   20.049834  41.142450
# ..            ...         ...        ...
# 236         Samoa -172.164851 -13.753243
# 237         Yemen   47.586762  15.909280
# 238  South Africa   25.083901 -29.000341
# 239        Zambia   27.774759 -13.458242
# 240      Zimbabwe   29.851441 -19.004204
#
# [241 rows x 3 columns]

# %%
data = raw_data.copy()

# %%
plt.scatter(data['Latitude'], data['Longitude'])

# %%
x = data.iloc[:,1:3]
x
# Out:
#       Longitude   Latitude
# 0    -69.982677  12.520880
# 1     66.004734  33.835231
# 2     17.537368 -12.293361
# 3    -63.064989  18.223959
# 4     20.049834  41.142450
# ..          ...        ...
# 236 -172.164851 -13.753243
# 237   47.586762  15.909280
# 238   25.083901 -29.000341
# 239   27.774759 -13.458242
# 240   29.851441 -19.004204
#
# [241 rows x 2 columns]

# %%
kmeans = KMeans(4)
kmeans.fit(x)
# Out:
# c:\Users\marqu\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4)

# %%
identified_clusters = kmeans.fit_predict(x)
identified_clusters
# Out:
# c:\Users\marqu\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# array([1, 0, 2, 1, 0, 0, 0, 0, 1, 0, 1, 2, 3, 2, 1, 3, 0, 0, 2, 0, 2, 2,
#        3, 0, 0, 1, 1, 0, 1, 0, 1, 1, 1, 1, 1, 3, 3, 2, 2, 0, 1, 3, 2, 2,
#        2, 2, 1, 1, 2, 2, 1, 1, 1, 1, 0, 0, 0, 0, 2, 1, 0, 1, 0, 1, 0, 2,
#        0, 0, 2, 0, 3, 1, 0, 0, 3, 2, 0, 0, 0, 2, 2, 2, 2, 2, 0, 1, 0, 1,
#        3, 1, 3, 2, 1, 0, 1, 0, 3, 0, 3, 3, 3, 0, 0, 0, 0, 0, 0, 1, 0, 0,
#        3, 3, 0, 2, 0, 3, 1, 1, 3, 0, 0, 3, 0, 2, 0, 1, 0, 3, 2, 0, 0, 0,
#        3, 1, 0, 0, 0, 2, 3, 1, 3, 0, 2, 0, 3, 0, 3, 3, 2, 2, 1, 2, 2, 3,
#        2, 3, 2, 3, 2, 1, 1, 0, 0, 3, 3, 3, 0, 0, 1, 1, 1, 3, 3, 3, 0, 1,
#        3, 0, 1, 0, 1, 0, 0, 3, 2, 0, 0, 2, 2, 2, 3, 2, 2, 3, 2, 1, 0, 2,
# ...

# %%
dataWithClusters = data.copy()
dataWithClusters['Clusters'] = identified_clusters
dataWithClusters
# Out:
#              name   Longitude   Latitude  Clusters
# 0           Aruba  -69.982677  12.520880         1
# 1     Afghanistan   66.004734  33.835231         0
# 2          Angola   17.537368 -12.293361         2
# 3        Anguilla  -63.064989  18.223959         1
# 4         Albania   20.049834  41.142450         0
# ..            ...         ...        ...       ...
# 236         Samoa -172.164851 -13.753243         1
# 237         Yemen   47.586762  15.909280         2
# 238  South Africa   25.083901 -29.000341         2
# 239        Zambia   27.774759 -13.458242         2
# 240      Zimbabwe   29.851441 -19.004204         2
#
# [241 rows x 4 columns]

# %%
plt.scatter(dataWithClusters['Latitude'], dataWithClusters['Longitude'], c=dataWithClusters['Clusters'], cmap='rainbow')
plt.show()

# %%
kmeans.inertia_
# Out:
# 260086.64553321703

# %%
wcss = []
cl_num = 11
for i in range(1, cl_num):
    kmeans = KMeans(i)
    kmeans.fit(x)
    wcss_iter = kmeans.inertia_
    wcss.append(wcss_iter)
# Out:
# c:\Users\marqu\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\marqu\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\marqu\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
wcss
# Out:
# [1413859.6798344273,
#  657012.0797586325,
#  325254.48120331316,
#  256573.086759343,
#  192212.4818949704,
#  177701.51225579926,
#  127560.17498392078,
#  109816.43803100535,
#  98145.72653492894,
#  79017.65594144235]

# %%
numberClusters = range(1,cl_num)
plt.plot(numberClusters, wcss)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Based on the Elbow Curve, plot several graphs with the appropriate amounts of clusters you believe would best fit the data.

# %% [markdown]
# Compare the scatter plots to determine which one to use in our further analysis.

# %% [markdown]
# <i>Hint: we already created the scatter plot for 4 clusters, so we only have to slightly alter our code.</i>

# %%
kmeans = KMeans(8)
kmeans.fit(x)
identified_clusters = kmeans.fit_predict(x)
dataWithClusters['Clusters'] = identified_clusters
plt.scatter(dataWithClusters['Latitude'], dataWithClusters['Longitude'], c=dataWithClusters['Clusters'], cmap='rainbow')
plt.show()
# Out:
# c:\Users\marqu\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\marqu\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
kmeans = KMeans(10)
kmeans.fit(x)
identified_clusters = kmeans.fit_predict(x)
dataWithClusters['Clusters'] = identified_clusters
plt.scatter(dataWithClusters['Latitude'], dataWithClusters['Longitude'], c=dataWithClusters['Clusters'], cmap='rainbow')
plt.show()
# Out:
# c:\Users\marqu\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\marqu\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
